# %%
# Importing The Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading The Data

song=pd.read_csv('final_songdata.csv')

# %% [markdown]
# # EDA(Exploratory Data Analysis) / Data Preprocessing

# %%
song.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
#    world/life  ...   sadness  feelings  danceability  loudness  acousticness  \
# 0    0.000598  ...  0.380299  0.117175      0.357739  0.454119      0.997992
# 1    0.443435  ...  0.001284  0.001284      0.331745  0.647540      0.954819
# 2    0.002770  ...  0.002770  0.225422      0.456298  0.585288      0.840361
# 3    0.001548  ...  0.225889  0.001548      0.686992  0.744404      0.083935
# 4    0.417772  ...  0.068800  0.001350      0.291671  0.646489      0.975904
#
#    instrumentalness   valence    energy       topic  age
# 0          0.901822  0.339448  0.137110     sadness  1.0
# 1          0.000002  0.325021  0.263240  world/life  1.0
# 2          0.000000  0.351814  0.139112       music  1.0
# 3          0.199393  0.775350  0.743736    romantic  1.0
# 4          0.000246  0.597073  0.394375    romantic  1.0
#
# [5 rows x 31 columns]

# %%
song.shape
# Out:
# (28372, 31)

# %%
# Removing Unwanted Columns

song=song.drop('Unnamed: 0',axis=1)

# %%
song.shape
# Out:
# (28372, 30)

# %%
song['genre'].unique()
# Out:
# array(['pop', 'country', 'blues', 'jazz', 'reggae', 'rock', 'hip hop'],
#       dtype=object)

# %%
song['genre'].value_counts()
# Out:
# genre
# pop        7042
# country    5445
# blues      4604
# rock       4034
# jazz       3845
# reggae     2498
# hip hop     904
# Name: count, dtype: int64

# %%
song.isna().sum()
# Out:
# artist_name                 0
# track_name                  0
# release_date                0
# genre                       0
# lyrics                      0
# len                         0
# dating                      0
# violence                    0
# world/life                  0
# night/time                  0
# shake the audience          0
# family/gospel               0
# romantic                    0
# communication               0
# obscene                     0
# music                       0
# movement/places             0
# light/visual perceptions    0
# family/spiritual            0
# like/girls                  0
# sadness                     0
# feelings                    0
# danceability                0
# loudness                    0
# acousticness                0
# instrumentalness            0
# valence                     0
# energy                      0
# topic                       0
# age                         0
# dtype: int64

# %%
song.duplicated().sum()
# Out:
# np.int64(0)

# %%
song[song.duplicated()].sum()
# Out:
# artist_name                   0
# track_name                    0
# release_date                  0
# genre                         0
# lyrics                        0
# len                           0
# dating                      0.0
# violence                    0.0
# world/life                  0.0
# night/time                  0.0
# shake the audience          0.0
# family/gospel               0.0
# romantic                    0.0
# communication               0.0
# obscene                     0.0
# music                       0.0
# movement/places             0.0
# light/visual perceptions    0.0
# family/spiritual            0.0
# like/girls                  0.0
# sadness                     0.0
# feelings                    0.0
# danceability                0.0
# loudness                    0.0
# acousticness                0.0
# instrumentalness            0.0
# valence                     0.0
# energy                      0.0
# topic                         0
# age                         0.0
# dtype: object

# %%
song.dtypes
# Out:
# artist_name                  object
# track_name                   object
# release_date                  int64
# genre                        object
# lyrics                       object
# len                           int64
# dating                      float64
# violence                    float64
# world/life                  float64
# night/time                  float64
# shake the audience          float64
# family/gospel               float64
# romantic                    float64
# communication               float64
# obscene                     float64
# music                       float64
# movement/places             float64
# light/visual perceptions    float64
# family/spiritual            float64
# like/girls                  float64
# sadness                     float64
# feelings                    float64
# danceability                float64
# loudness                    float64
# acousticness                float64
# instrumentalness            float64
# valence                     float64
# energy                      float64
# topic                        object
# age                         float64
# dtype: object

# %%
song['artist_name'].value_counts().head()
# Out:
# artist_name
# johnny cash        190
# ella fitzgerald    188
# dean martin        146
# willie nelson      131
# george jones       107
# Name: count, dtype: int64

# %%
song['track_name'].value_counts().head()
# Out:
# track_name
# tonight        17
# stay           15
# hold on        15
# without you    14
# home           13
# Name: count, dtype: int64

# %%
song['topic'].value_counts()
# Out:
# topic
# sadness       6096
# violence      5710
# world/life    5420
# obscene       4882
# music         2303
# night/time    1825
# romantic      1524
# feelings       612
# Name: count, dtype: int64

# %%
# Getting The Required Columns From The Data

song_1=pd.concat([song.iloc[:,0:6],song.iloc[:,22:30]],axis=1)
song_1.head()
# Out:
#             artist_name            track_name  release_date genre  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1         frankie laine             i believe          1950   pop
# 2           johnnie ray                   cry          1950   pop
# 3           pérez prado              patricia          1950   pop
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len  danceability  \
# 0  hold time feel break feel untrue convince spea...   95      0.357739
# 1  believe drop rain fall grow believe darkest ni...   51      0.331745
# 2  sweetheart send letter goodbye secret feel bet...   24      0.456298
# 3  kiss lips want stroll charm mambo chacha merin...   54      0.686992
# 4  till darling till matter know till dream live ...   48      0.291671
#
#    loudness  acousticness  instrumentalness   valence    energy       topic  \
# 0  0.454119      0.997992          0.901822  0.339448  0.137110     sadness
# 1  0.647540      0.954819          0.000002  0.325021  0.263240  world/life
# 2  0.585288      0.840361          0.000000  0.351814  0.139112       music
# 3  0.744404      0.083935          0.199393  0.775350  0.743736    romantic
# 4  0.646489      0.975904          0.000246  0.597073  0.394375    romantic
#
#    age
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0

# %%
song_1.shape
# Out:
# (28372, 14)

# %%
# Renaming The Columns

song_1.rename({'artist_name': 'artists', 'track_name': 'songs','release_date': 'release_year','len': 'duration'},axis=1,inplace=True)
song_1.head()
# Out:
#                 artists                 songs  release_year genre  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1         frankie laine             i believe          1950   pop
# 2           johnnie ray                   cry          1950   pop
# 3           pérez prado              patricia          1950   pop
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  duration  danceability  \
# 0  hold time feel break feel untrue convince spea...        95      0.357739
# 1  believe drop rain fall grow believe darkest ni...        51      0.331745
# 2  sweetheart send letter goodbye secret feel bet...        24      0.456298
# 3  kiss lips want stroll charm mambo chacha merin...        54      0.686992
# 4  till darling till matter know till dream live ...        48      0.291671
#
#    loudness  acousticness  instrumentalness   valence    energy       topic  \
# 0  0.454119      0.997992          0.901822  0.339448  0.137110     sadness
# 1  0.647540      0.954819          0.000002  0.325021  0.263240  world/life
# 2  0.585288      0.840361          0.000000  0.351814  0.139112       music
# 3  0.744404      0.083935          0.199393  0.775350  0.743736    romantic
# 4  0.646489      0.975904          0.000246  0.597073  0.394375    romantic
#
#    age
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0

# %%
# Checking The Outliers

song_2= song_1[song_1.genre.isin(song_1.genre.value_counts().index)]
sns.boxplot(x='genre',y='release_year',data=song_2)
plt.show()

# %%
# Removing The Outliers

# Define a function to remove outliers based on IQR
def remove_outliers(df, column, threshold=1.5):
    q1 = df[column].quantile(0.25)
    q2 = df[column].quantile(0.75)
    iqr = q2 - q1
    lower_bound = q1 - threshold * iqr
    upper_bound = q2 + threshold * iqr
    df_no_outliers = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_no_outliers

# Remove outliers for each genre
song_2_no_outliers = song_2.groupby('genre').apply(lambda x: remove_outliers(x, 'release_year'))

# Flatten the grouped DataFrame
song_2_no_outliers = song_2_no_outliers.reset_index(drop=True)
# Out:
# C:\Users\pnikh\AppData\Local\Temp\ipykernel_17860\3303875895.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   song_2_no_outliers = song_2.groupby('genre').apply(lambda x: remove_outliers(x, 'release_year'))

# %%
# Create a boxplot without outliers

plt.figure(figsize=(12, 8))
sns.boxplot(x='genre', y='release_year', data=song_2_no_outliers, showfliers=False)
plt.title('Boxplot of Release Year for Each Genre (No Outliers)')
plt.show()

# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numerical columns for box plot
numerical_columns = ['release_year', 'duration', 'danceability', 'loudness', 'acousticness', 'instrumentalness', 'valence', 'energy', 'topic', 'age']

# Set a larger figure size
plt.figure(figsize=(18, 10))

# Create box plots for numerical columns
sns.boxplot(data=song_1[numerical_columns], width=0.7, showfliers=True, palette="Set3")

# Add title and labels
plt.title('Box Plots of Numerical Features', fontsize=16)
plt.xlabel('Numerical Features', fontsize=14)
plt.ylabel('Values', fontsize=14)

# Show the plot
plt.show()

# %%
sns.histplot(song_1['release_year'],bins=60)
plt.title('Histogram of Release Year')
plt.xlabel('Variable Values')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(song_1['genre'], bins=30)
plt.title('Histogram of Variable')
plt.xlabel('Variable Values')
plt.ylabel('Frequency')
plt.show()

# %%
#song_1['songs'] = song_1['songs'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)

#plt.figure(figsize=(20,8))
#sns.countplot(x='songs', data=song_1)
#plt.title('Count Plot of Songs')
#plt.xlabel('Songs')
#plt.ylabel('Count')
#plt.xticks(rotation=45, ha='right')
#plt.show()

# %%
plt.figure(figsize=(18,10))
sns.countplot(x='genre', data=song_1)
plt.title('Count Plot of Genre')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Assuming you want to visualize the top 20 songs and top 10 artists
top_songs = song_1['songs'].value_counts().head(20).index
top_artists = song_1['artists'].value_counts().head(10).index

subset_data = song_1[(song_1['songs'].isin(top_songs)) & (song_1['artists'].isin(top_artists))]

plt.figure(figsize=(12, 10))
sns.heatmap(pd.crosstab(subset_data['songs'], subset_data['artists']), cmap='viridis', annot=True, fmt='d')
plt.title('Heatmap of Songs and Artists')
plt.xlabel('Artists')
plt.ylabel('Songs')
plt.show()

# %%
top_years = song_1['release_year'].value_counts().head(20).index
top_artists = song_1['artists'].value_counts().head(10).index

subset_data = song_1[(song_1['release_year'].isin(top_years)) & (song_1['artists'].isin(top_artists))]

plt.figure(figsize=(12, 10))
sns.heatmap(pd.crosstab(subset_data['release_year'], subset_data['artists']), cmap='viridis', annot=True, fmt='d')
plt.title('Heatmap of Release year and Artists')
plt.xlabel('Artists')
plt.ylabel('Release Year')
plt.show()

# %%
top_years = song_1['genre'].value_counts().head(7).index
top_artists = song_1['artists'].value_counts().head(20).index

subset_data = song_1[(song_1['genre'].isin(top_years)) & (song_1['artists'].isin(top_artists))]

plt.figure(figsize=(12, 10))
sns.heatmap(pd.crosstab(subset_data['genre'], subset_data['artists']), cmap='viridis', annot=True, fmt='d')
plt.title('Heatmap of Genre and Artists')
plt.xlabel('Artists')
plt.ylabel('Genre')
plt.show()

# %%
top_years = song_1['release_year'].value_counts().head(20).index
top_artists = song_1['genre'].value_counts().head(7).index

subset_data = song_1[(song_1['release_year'].isin(top_years)) & (song_1['genre'].isin(top_artists))]

plt.figure(figsize=(12, 10))
sns.heatmap(pd.crosstab(subset_data['release_year'], subset_data['genre']), cmap='viridis', annot=True, fmt='d')
plt.title('Heatmap of Release Year and Genre')
plt.xlabel('Genre')
plt.ylabel('Release Year')
plt.show()

# %%
# Converting Categorical columns to Numerical
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
song_2['topic'] = label_encoder.fit_transform(song_2['topic'].fillna(''))
song_2.head()
# Out:
#                 artists                 songs  release_year genre  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1         frankie laine             i believe          1950   pop
# 2           johnnie ray                   cry          1950   pop
# 3           pérez prado              patricia          1950   pop
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  duration  danceability  \
# 0  hold time feel break feel untrue convince spea...        95      0.357739
# 1  believe drop rain fall grow believe darkest ni...        51      0.331745
# 2  sweetheart send letter goodbye secret feel bet...        24      0.456298
# 3  kiss lips want stroll charm mambo chacha merin...        54      0.686992
# 4  till darling till matter know till dream live ...        48      0.291671
#
#    loudness  acousticness  instrumentalness   valence    energy  topic  age
# 0  0.454119      0.997992          0.901822  0.339448  0.137110      5  1.0
# 1  0.647540      0.954819          0.000002  0.325021  0.263240      7  1.0
# 2  0.585288      0.840361          0.000000  0.351814  0.139112      1  1.0
# 3  0.744404      0.083935          0.199393  0.775350  0.743736      4  1.0
# 4  0.646489      0.975904          0.000246  0.597073  0.394375      4  1.0

# %%
#song_2['Songs-Artists'] = song_2['songs'] + ' - ' + song_2['artists']
#song_2.insert(0, 'Songs-Artists', song_2.pop('Songs-Artists'))
#song_2.head()

# %%
#song_2['Lyrics-Genre'] = song_2['lyrics'] + ' - ' + song_2['genre']
#song_2.insert(1, 'Lyrics-Genre', song_2.pop('Lyrics-Genre'))
#song_2.head()

# %%
#song_3=song_2.drop(['artists','songs','lyrics','genre'],axis=1)
#song_3.head()

# %%
#value_counts_sorted = song_3['release_year'].value_counts().sort_index()
#value_counts_sorted

# %%
song_2.head()
# Out:
#                 artists                 songs  release_year genre  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1         frankie laine             i believe          1950   pop
# 2           johnnie ray                   cry          1950   pop
# 3           pérez prado              patricia          1950   pop
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  duration  danceability  \
# 0  hold time feel break feel untrue convince spea...        95      0.357739
# 1  believe drop rain fall grow believe darkest ni...        51      0.331745
# 2  sweetheart send letter goodbye secret feel bet...        24      0.456298
# 3  kiss lips want stroll charm mambo chacha merin...        54      0.686992
# 4  till darling till matter know till dream live ...        48      0.291671
#
#    loudness  acousticness  instrumentalness   valence    energy  topic  age
# 0  0.454119      0.997992          0.901822  0.339448  0.137110      5  1.0
# 1  0.647540      0.954819          0.000002  0.325021  0.263240      7  1.0
# 2  0.585288      0.840361          0.000000  0.351814  0.139112      1  1.0
# 3  0.744404      0.083935          0.199393  0.775350  0.743736      4  1.0
# 4  0.646489      0.975904          0.000246  0.597073  0.394375      4  1.0

# %% [markdown]
# # Model Building

# %%
pivot_table = pd.pivot_table(song_2, values=['danceability', 'loudness', 'acousticness', 'instrumentalness', 'valence', 'energy'], index=['songs','artists','genre','lyrics'], columns='release_year', fill_value=0)
pivot_table.head()
# Out:
#                                                                                                             acousticness  \
# release_year                                                                                                        1950
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...          0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...          0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...          0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...          0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...          0.0
#
#                                                                                                                   \
# release_year                                                                                                1951
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                1952
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                1953
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                1954
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                1955
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                1956
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                1957
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                1958
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                1959
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                              ...  \
# release_year                                                                                                 ...
# songs                   artists                   genre  lyrics                                              ...
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  ...
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  ...
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  ...
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  ...
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  ...
#
#                                                                                                             valence  \
# release_year                                                                                                   2010
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...     0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...     0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...     0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...     0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...     0.0
#
#                                                                                                                   \
# release_year                                                                                                2011
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                2012
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                2013
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                2014
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                2015
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                2016
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                2017
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#                                                                                                                   \
# release_year                                                                                                2018
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
#
# release_year                                                                                                2019
# songs                   artists                   genre  lyrics
# "40"                    u2                        rock   wait patiently lord incline hear bring miry sin...  0.0
# "african head charge"   dub syndicate             reggae sew eye shut afraid try tell inside answer ease...  0.0
# "b" movie box car blues the blues brothers        blues  seven hours days take away night sleep take awa...  0.0
# "belle" of the earth    manfred mann's earth band blues  road subway lie ahead music sound go dead life ...  0.0
# "it’s a good day"       kay starr                 jazz   good sing song good move good wrong good mornin...  0.0
#
# [5 rows x 420 columns]

# %%
# Sparse matrices are especially useful when dealing with large datasets in machine learning, where most of the features might be zero for each sample.
from scipy.sparse import csr_matrix

song_features_df_matrix = csr_matrix(pivot_table.values)
song_features_df_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 162359 stored elements and shape (28372, 420)>

# %%
from sklearn.neighbors import NearestNeighbors


model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'auto')
model_knn.fit(song_features_df_matrix)
# Out:
# NearestNeighbors(metric='cosine')

# %%
# Parameter Tunning
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors': [5, 10, 15, 20]}
model_knn = NearestNeighbors(metric='cosine', algorithm='auto')
grid_search = GridSearchCV(model_knn, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(song_features_df_matrix)
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'n_neighbors': 5}

# %%
pivot_table.shape
# Out:
# (28372, 420)

# %%
from scipy.sparse import csr_matrix

song_features_df_matrix = csr_matrix(pivot_table.values)

from sklearn.neighbors import NearestNeighbors


model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'auto',n_neighbors=5)
model_knn.fit(song_features_df_matrix)
# Out:
# NearestNeighbors(metric='cosine')

# %%
#query_index = np.random.choice(pivot_table.shape[0])
#print(query_index)
#distances, indices = model_knn.kneighbors(pivot_table.iloc[query_index,:].values.reshape(1, -1), n_neighbors = 5)

# %%
# Assume user_defined_index is the index you want to use
#user_defined_index = 0  # Replace 42 with the desired index
#print("User-defined Index:", user_defined_index)

# Query the nearest neighbors for the specified index
#distances, indices = model_knn.kneighbors(pivot_table.iloc[user_defined_index, :].values.reshape(1, -1), n_neighbors=5)

# %%
# Assume user_defined_index is the index you want to use
#user_defined_index = 0  # Replace 42 with the desired index
#print("User-defined Index:", user_defined_index)

# Retrieve the data corresponding to the specified index
#selected_data = pivot_table.iloc[user_defined_index, :]

# Print the selected data
#print("Selected Data:")
#print(selected_data)

# Query the nearest neighbors for the specified index
#distances, indices = model_knn.kneighbors(selected_data.values.reshape(1, -1), n_neighbors=5)

# %%
# Example: Get recommendations for a specific song name
song_name = '"african head charge"'  # Replace 'Your_Song_Name' with the name of the song you want recommendations for

# Locate the index of the song in the pivot_table DataFrame
song_index = pivot_table.index.get_loc(song_name)

# Retrieve the data corresponding to the specified index
selected_data = pivot_table.iloc[song_index, :]

# Print the selected data
print("Selected Data:")
print(selected_data)

# Query the nearest neighbors for the specified index
distances, indices = model_knn.kneighbors(selected_data.values.reshape(1, -1), n_neighbors=5)
# Out:
# Selected Data:
#                                                                                               acousticness  \
# release_year                                                                                          1950
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...          0.0
#
#                                                                                                     \
# release_year                                                                                  1951
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  1952
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  1953
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  1954
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  1955
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  1956
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  1957
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  1958
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  1959
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                ...  \
# release_year                                                                                   ...
# songs                 artists       genre  lyrics                                              ...
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  ...
#
#                                                                                               valence  \
# release_year                                                                                     2010
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...     0.0
#
#                                                                                                     \
# release_year                                                                                  2011
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  2012
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  2013
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  2014
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  2015
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  2016
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  2017
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#                                                                                                     \
# release_year                                                                                  2018
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
#
# release_year                                                                                  2019
# songs                 artists       genre  lyrics
# "african head charge" dub syndicate reggae sew eye shut afraid try tell inside answer ease...  0.0
#
# [1 rows x 420 columns]

# %%
print('Recommendations for {0}:\n'.format(song_name))
for i in range(0, len(distances.flatten())):
    if i == 0:
        continue  # Skip the first neighbor, as it will be the query point itself
    print('{0}: {1}, with distance of {2}'.format(i, pivot_table.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recommendations for "african head charge":
#
# 1: ('dub marcus say', 'steel pulse', 'reggae', 'pulse music songs write hinds house write phonso songs publish pulse music produce pitterson productions engineer thompson nielson lauritsen musik makers stepper mcqueen bass grizzly nesbitt drum selwyn bumbo keyboards vocals phonso guitar vocals hinds guitar vocals gabbidon lead guitar'), with distance of 0.00277123044451677
# 2: ('siamese twins', 'the cure', 'rock', 'choose eternity like fall angels world disappear laugh like flesh blood kiss colour kiss writhe light voodoo smile siamese twin girl window look hour fall apart break inside fall apart wall ceiling time push blade hand slowly stairs room like dance pocket worm skin glow grow arm outstretched legs morning cry leave remember voice walk away grow talk smile scream need fade spin fade spin sing loud laugh like like like'), with distance of 0.0035313864436469222
# 3: ('verse 8', 'jah shaka', 'reggae', 'jesusontherocks energy catalyst difference change plenty alittle force push flip shit work board hurt absorb berserk like korg light like doors scksolo tribe worldwide tell bitch nigga hide swing niggas south like nigga nemo bear strip shit finna nevemind read nigga mind fine sublime pass slim tell time time theyll channel news door cosign nigga sekito chasin niggas go bitch brag shikamaru shit drag super sonic dash mega mafuckin blast dead opps smokin hat understand brothers hold shit fold expose self self shit lack respect word easy fake friends gimme heebiejeebies fuck ball jesusontherocks fuck ball like verse beat like wave silver surf galactic purpose certain purpose see believe world need bitch like serenaand trap eater scksolo niggas decline leave tribe nigga piece want mouse turn facts logo nigga steal shirt nigga niggas take note lungs asthma attack pull niggas like daxter prism tribe shit bitch handle ask bitch dabble like candle wish nigga burn like mantle stay yeah thats leave right die channel energy thaniel summer sekito spiegel bang swear feel pain swear swear change rid round niggas people gonna talk niggas threat fall fallin slow descent'), with distance of 0.005789622850131071
# 4: ('love and devotion', 'jimmy riley', 'reggae', 'girl promise devotion girl promise scar girl promise devotion girl promise scar girl promise girl promise want girl promise devotion girl promise scar girl promise blue girl promise true turn girl promise devotion girl promise scar girl promise devotion girl promise scar girl promise devotion girl promise scar girl promise girl promise girl promise devotion girl promise scar scar scar'), with distance of 0.014319266109652395

# %%
# Create a DataFrame to display the results
Neighbors_Df = pd.DataFrame({'Neighbor Index': indices.flatten(),'Distance': distances.flatten()})
# Fetch additional information from pivot_table using neighbor indices
Neighbors_Df['Songs'] = pivot_table.index[Neighbors_Df['Neighbor Index']].get_level_values('songs').tolist()
Neighbors_Df['Artists'] = pivot_table.index[Neighbors_Df['Neighbor Index']].get_level_values('artists').tolist()
Neighbors_Df['Genre'] = pivot_table.index[Neighbors_Df['Neighbor Index']].get_level_values('genre').tolist()
Neighbors_Df['lyrics'] = pivot_table.index[Neighbors_Df['Neighbor Index']].get_level_values('lyrics').tolist()
# Rearrange the columns
Neighbors_Df = Neighbors_Df[['Songs', 'Artists','Genre','lyrics','Neighbor Index', 'Distance']]


# Sort the DataFrame by the 'Distance' column in ascending order
Neighbors_Df = Neighbors_Df.sort_values(by='Distance')
Neighbors_Df.head()
# Out:
#                    Songs        Artists   Genre  \
# 0  "african head charge"  dub syndicate  reggae
# 1         dub marcus say    steel pulse  reggae
# 2          siamese twins       the cure    rock
# 3                verse 8      jah shaka  reggae
# 4      love and devotion    jimmy riley  reggae
#
#                                               lyrics  Neighbor Index  Distance
# 0  sew eye shut afraid try tell inside answer eas...               1  0.000000
# 1  pulse music songs write hinds house write phon...            6012  0.002771
# 2  choose eternity like fall angels world disappe...           20485  0.003531
# 3  jesusontherocks energy catalyst difference cha...           25853  0.005790
# 4  girl promise devotion girl promise scar girl p...           14423  0.014319
